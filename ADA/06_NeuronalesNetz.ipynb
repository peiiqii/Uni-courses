# %% [markdown]
# Dieses Notebook zeigt, wie man ein spezielles Rekurrentes Neuronales Netz (LSTM) zur Vorhersage von Energieverbrauchsdaten trainieren kann.
# Hierfür werden die Bibliotheken keras, sowie sci-kit learn verwendet.
# Das Notebook orientiert sich an folgendem Tutorial: https://www.elab2go.de/demo-py5/ (Autoren: Prof. Dr. Eva Maria Kiss, B. Sc. Franc Willy Pouhela, M. Sc. Anke Welz)

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import math

# matplotlib und seaborn zum Plotten
import matplotlib.pyplot as plt
import seaborn as sns

# scikit-learn für Überwachtes Lernen
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import max_error

# keras für Neuronale Netze
import tensorflow as tf
import keras as keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.utils import plot_model
from keras import activations

# Für das Darstellen von Bildern im SVG-Format
import graphviz as gv
import pydot
from keras.utils import model_to_dot
from IPython.display import SVG

# %%
# Daten einlesen
data = pd.read_csv('https://www.elab2go.de/demo-py5/opsd_2016-2019.csv')

# %%
data.head()
# Out:
#         Datum  Verbrauch    Wind  Solar  Wind+Solar
# 0  2016-01-01    1007.11  107.21  18.56      125.77
# 1  2016-01-02    1147.89  409.62   9.40      419.02
# 2  2016-01-03    1130.63  406.30  13.52      419.82
# 3  2016-01-04    1385.93  278.46  10.08      288.54
# 4  2016-01-05    1430.11  206.47  12.55      219.02

# %%
data.tail()
# Out:
#            Datum  Verbrauch    Wind  Solar  Wind+Solar
# 1456  2019-12-27    1172.20  146.59  20.96      167.55
# 1457  2019-12-28    1141.33  159.13  36.24      195.36
# 1458  2019-12-29    1087.07  349.84  54.91      404.75
# 1459  2019-12-30    1200.05  669.27  53.22      722.49
# 1460  2019-12-31    1124.93  425.22  36.56      461.79

# %% [markdown]
# # Aufgabe 1: Datenvorbereitung
#
#
# * a) Überprüfen Sie, ob in dem Datensatz NaN enthalten sind. Falls ja, überlegen Sie sich, wie Sie damit am besten umgehen.
# *   b) Ist es sinnvoll, mit allen Merkmalen fortzufahren? Was müssen Sie tun um diese Frage beantworten zu können?
# *   c) Bringen Sie die Spalte "Datum" in ein geeignetes Format und indizieren Sie das dataframe mit dieser Spalte

# %%
# Frage 1 a) Überprüfen auf NaN

data.isna().any()

# Umgang mit NaN:
# Entfernen von NaN:  data = data.dropna(inplace=True, axis=0)
# Out:
# Datum         False
# Verbrauch     False
# Wind          False
# Solar         False
# Wind+Solar    False
# dtype: bool

# %% [markdown]
# **Frage 1 b) Ist es sinnvoll, mit allen Merkmalen fortzufahren? Was müssen Sie tun um diese Frage beantworten zu können?** <br>
# Nein. Die Merkmalen "Wind, Solar und Wind+Solar" sind irrelevant, da wir können Energieverbrauchsdaten nur mit Datum und Verbrauch Merkmalen erhalten

# %%
# Frage 1 c)  Bringen Sie die Spalte "Datum" in ein geeignetes Format und indizieren Sie das dataframe mit dieser Spalte
print("Datentyp von der Datum-Spalte: ", data["Datum"].dtypes)

# Die Spalte Datum soll im Format datetime umgewandelt werden.
data["Datum"] = pd.to_datetime(data["Datum"])
print("Datentyp von der Datum-Spalte nach Umwandlung: ", data["Datum"].dtypes)
data.set_index("Datum", inplace=True)
# Out:
# Datentyp von der Datum-Spalte:  object
# Datentyp von der Datum-Spalte nach Umwandlung:  datetime64[ns]

# %%
# Plotten des Stromverbrauchs. Der Stromverbrauch soll später mithilfe des Neuronalen Netzes vorhergesagt werden.

sns.set(rc={'figure.figsize':(12, 4)})
sns.set_color_codes('bright')

ax = data['Verbrauch'].plot(linewidth=1, color='b', marker = '.')
ax.set_title('Täglicher Stromverbrauch')
ax.set_xlabel('Datum');
ax.set_ylabel('GwH');

# %% [markdown]
# # Aufgabe 2
#
# Im nächsten Codeblock werden zeitlich versetzte Merkmale (sogenannte Lagged Features) erzeugt.
#
# *   a) Was macht dabei die Funktion shift()? Schauen Sie in der pandas Dokumentation nach!
# *   b) Was macht die Funktion concat()? Schauen Sie auch das in der pandas Dokumentation nach!
# *   c) Führen Sie die untenstehende Zelle aus und Lassen Sie sich anschließend die ersten 10 Zeilen des neu erzeugten dataframes ausgeben. Hat das Erzeugen der zeitlich versetzten Merkmale erfolgreich funktioniert?

# %% [markdown]
# # Antworten
#
#
#
# **a. Was macht dabei die Funktion shift()? Schauen Sie in der pandas Dokumentation nach!** <br>
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shift.html <br>
# ``shift()`` verschiebt die Daten in einer Reihe oder in einer Spalte des DataFrame um eine bestimmte Anzahl von Perioden nach unten (positive) oder nach oben (negative). <br><br>
# **b. Was macht die Funktion concat()? Schauen Sie auch das in der pandas Dokumentation nach!** <br>
# https://pandas.pydata.org/docs/reference/api/pandas.concat.html <br>
# ``concat()`` - um DataFrames horizontal oder vertikal aneinander zu hängen/konkatenieren <br><br>
#
# **c. Hat das Erzeugen der zeitlich versetzten Merkmale erfolgreich funktioniert**<br>
# ja, da sieht man eine Verschiebung des Verbrauchs pro Datum
# <br><br>

# %%
# Erzeuge zeitlich versetzte Merkmale (lagged features)

# ein neues DataFrame 'consumption' wird erstellt, das nur die Spalte 'Verbrauch' aus dem ursprünglichen DataFrame data enthält
consumption = pd.DataFrame(data['Verbrauch'])

# die 'Verbrauch'-Spalte wird um verschiedene Zeitverzögerungen (1 bis 7 Tagen) verschoben.
# Die Werte werden dann horizontal (axis=1) konkateniert.
# Das Ergebnis wird zu data hinzugefügt
data = pd.concat([consumption.shift(7),consumption.shift(6), consumption.shift(5), consumption.shift(4),
                  consumption.shift(3), consumption.shift(2), consumption.shift(1), data[['Verbrauch']]], axis=1)

# die Spalten werden bennant
data.columns =  ['t-7', 't-6', 't-5', 't-4', 't-3', 't-2', 't-1', 'Verbrauch']

data.head()

data.dropna(inplace=True) # Entfernung von NaN-Werten

# %%
data.head(10)
# Out:
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2016-01-08  1007.11  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61
# 2016-01-09  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35
# 2016-01-10  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35  1236.50
# 2016-01-11  1385.93  1430.11  1375.73  1480.61  1469.35  1236.50  1133.10
# 2016-01-12  1430.11  1375.73  1480.61  1469.35  1236.50  1133.10  1493.80
# 2016-01-13  1375.73  1480.61  1469.35  1236.50  1133.10  1493.80  1517.06
# 2016-01-14  1480.61  1469.35  1236.50  1133.10  1493.80  1517.06  1525.13
# 2016-01-15  1469.35  1236.50  1133.10  1493.80  1517.06  1525.13  1518.12
# 2016-01-16  1236.50  1133.10  1493.80  1517.06  1525.13  1518.12  1515.73
# 2016-01-17  1133.10  1493.80  1517.06  1525.13  1518.12  1515.73  1287.07
#
#             Verbrauch
# Datum
# 2016-01-08    1469.35
# 2016-01-09    1236.50
# 2016-01-10    1133.10
# 2016-01-11    1493.80
# 2016-01-12    1517.06
# 2016-01-13    1525.13
# 2016-01-14    1518.12
# 2016-01-15    1515.73
# 2016-01-16    1287.07
# 2016-01-17    1208.63

# %%
# Daten in Trainings- und Testset aufspalten

TEST_SPLIT = 0.1
#data = data.drop(columns = ['Wind', 'Solar'])
train_size = int(len(data) * (1-TEST_SPLIT))
test_size = len(data) - train_size
train = data.iloc[0:train_size]
test = data.iloc[train_size:len(data)]
print("Trainingsdaten:")
print(train.head())
print(train.tail())
print("Testdaten:")
print(test.head())
print(test.tail())
# Out:
# Trainingsdaten:
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2016-01-08  1007.11  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61
# 2016-01-09  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35
# 2016-01-10  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35  1236.50
# 2016-01-11  1385.93  1430.11  1375.73  1480.61  1469.35  1236.50  1133.10
# 2016-01-12  1430.11  1375.73  1480.61  1469.35  1236.50  1133.10  1493.80
#
#             Verbrauch
# Datum
# 2016-01-08    1469.35
# 2016-01-09    1236.50
# 2016-01-10    1133.10
# 2016-01-11    1493.80
# 2016-01-12    1517.06
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2019-08-03  1141.75  1055.72  1337.17  1380.32  1361.27  1330.42  1305.06
# 2019-08-04  1055.72  1337.17  1380.32  1361.27  1330.42  1305.06  1086.43
# 2019-08-05  1337.17  1380.32  1361.27  1330.42  1305.06  1086.43  1001.21
# 2019-08-06  1380.32  1361.27  1330.42  1305.06  1086.43  1001.21  1278.04
# 2019-08-07  1361.27  1330.42  1305.06  1086.43  1001.21  1278.04  1315.79
#
#             Verbrauch
# Datum
# 2019-08-03    1086.43
# 2019-08-04    1001.21
# 2019-08-05    1278.04
# 2019-08-06    1315.79
# 2019-08-07    1324.10
# Testdaten:
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2019-08-08  1330.42  1305.06  1086.43  1001.21  1278.04  1315.79  1324.10
# 2019-08-09  1305.06  1086.43  1001.21  1278.04  1315.79  1324.10  1326.62
# 2019-08-10  1086.43  1001.21  1278.04  1315.79  1324.10  1326.62  1318.76
# 2019-08-11  1001.21  1278.04  1315.79  1324.10  1326.62  1318.76  1132.40
# 2019-08-12  1278.04  1315.79  1324.10  1326.62  1318.76  1132.40  1043.49
#
#             Verbrauch
# Datum
# 2019-08-08    1326.62
# 2019-08-09    1318.76
# 2019-08-10    1132.40
# 2019-08-11    1043.49
# 2019-08-12    1299.03
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2019-12-27  1354.26  1206.42  1140.68  1214.86  1112.49  1042.24  1042.69
# 2019-12-28  1206.42  1140.68  1214.86  1112.49  1042.24  1042.69  1172.20
# 2019-12-29  1140.68  1214.86  1112.49  1042.24  1042.69  1172.20  1141.33
# 2019-12-30  1214.86  1112.49  1042.24  1042.69  1172.20  1141.33  1087.07
# 2019-12-31  1112.49  1042.24  1042.69  1172.20  1141.33  1087.07  1200.05
#
#             Verbrauch
# Datum
# 2019-12-27    1172.20
# 2019-12-28    1141.33
# 2019-12-29    1087.07
# 2019-12-30    1200.05
# 2019-12-31    1124.93

# %%
# Daten auf den Wertebereich [0, 1] skalieren

scaler = MinMaxScaler(feature_range = (0,1))

train_s = scaler.fit_transform(np.array(train))
test_s = scaler.fit_transform(np.array(test))

print("Trainingsdaten (unskaliert)\n")
print(train.head(3))
print("\nTrainingsdaten (skaliert)\n")
train_s = pd.DataFrame( train_s , columns = data.columns)
train_s = train_s.set_index(train.index )
print(train_s.head(3))

print("Testdaten (unskaliert)\n")
print(test.head(3))
print("\nTestdaten (skaliert)\n")
test_s = pd.DataFrame( test_s , columns = data.columns)
test_s = test_s.set_index(test.index )
print(test_s.head(3))
# Out:
# Trainingsdaten (unskaliert)
#
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2016-01-08  1007.11  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61
# 2016-01-09  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35
# 2016-01-10  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35  1236.50
#
#             Verbrauch
# Datum
# 2016-01-08    1469.35
# 2016-01-09    1236.50
# 2016-01-10    1133.10
#
# Trainingsdaten (skaliert)
#
#                  t-7       t-6       t-5       t-4       t-3       t-2  \
# Datum
# 2016-01-08  0.102986  0.303656  0.279054  0.642962  0.705937  0.628423
# 2016-01-09  0.303656  0.279054  0.642962  0.705937  0.628423  0.777920
# 2016-01-10  0.279054  0.642962  0.705937  0.628423  0.777920  0.761870
#
#                  t-1  Verbrauch
# Datum
# 2016-01-08  0.777920   0.761870
# 2016-01-09  0.761870   0.429962
# 2016-01-10  0.429962   0.282574
# Testdaten (unskaliert)
#
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2019-08-08  1330.42  1305.06  1086.43  1001.21  1278.04  1315.79  1324.10
# 2019-08-09  1305.06  1086.43  1001.21  1278.04  1315.79  1324.10  1326.62
# 2019-08-10  1086.43  1001.21  1278.04  1315.79  1324.10  1326.62  1318.76
#
#             Verbrauch
# Datum
# 2019-08-08    1326.62
# 2019-08-09    1318.76
# 2019-08-10    1132.40
#
# Testdaten (skaliert)
#
#                  t-7       t-6       t-5       t-4       t-3       t-2  \
# Datum
# 2019-08-08  0.560969  0.517756  0.145214  0.000000  0.449950  0.516926
# 2019-08-09  0.517756  0.145214  0.000000  0.471714  0.516926  0.531669
# 2019-08-10  0.145214  0.000000  0.471714  0.536039  0.531669  0.536140
#
#                  t-1  Verbrauch
# Datum
# 2019-08-08  0.531669   0.536140
# 2019-08-09  0.536140   0.522195
# 2019-08-10  0.522195   0.191558

# %%
# In Merkmale und Label aufteilen

X_train = train_s.drop(columns = ['Verbrauch'])
y_train = pd.DataFrame(train_s['Verbrauch'])

print(X_train.head())
print(y_train.head())
# Out:
#                  t-7       t-6       t-5       t-4       t-3       t-2  \
# Datum
# 2016-01-08  0.102986  0.303656  0.279054  0.642962  0.705937  0.628423
# 2016-01-09  0.303656  0.279054  0.642962  0.705937  0.628423  0.777920
# 2016-01-10  0.279054  0.642962  0.705937  0.628423  0.777920  0.761870
# 2016-01-11  0.642962  0.705937  0.628423  0.777920  0.761870  0.429962
# 2016-01-12  0.705937  0.628423  0.777920  0.761870  0.429962  0.282574
#
#                  t-1
# Datum
# 2016-01-08  0.777920
# 2016-01-09  0.761870
# 2016-01-10  0.429962
# 2016-01-11  0.282574
# 2016-01-12  0.796722
#             Verbrauch
# Datum
# 2016-01-08   0.761870
# 2016-01-09   0.429962
# 2016-01-10   0.282574
# 2016-01-11   0.796722
# 2016-01-12   0.829877

# %%
TIMESTEPS = 7 # Länge eines gleitenden Zeitfensters
UNITS = 10 # Ausgabedimension einer einzelnen LSTM-Schicht
N_LAYER = 2 # Anzahl an LSTM-Schichten

# Initialisiere ein sequentielles Modell (Modell mit mehreren Schichten)
model = Sequential(name='sequential')

#Füge so viele Schichten hinzu, wie in N_LAYER angegeben
for i in range(N_LAYER):

  lstm_layer = LSTM(units = UNITS, # Dimension der Ausgabe
                    input_shape=(TIMESTEPS,1), # Dimension der Eingabe (1. Dimension entspricht Anzahl Zeitschritte, 2. Dimension:  1, da nur ein Merkmal = Verbrauch über die Zeit betrachtet wird (univariates Problem) )
                    return_sequences=True, # wir wollen die gesamte Ausgabesequenz der jeweiligen LSTM-Schicht in die nächste LSTM-Schicht weitergeben können
                    name = 'lstm_' + str(i+1)) # Schichten werden mit "lstm_" + Schichtnummer benannt

  model.add(lstm_layer) # Schicht dem Modell hinzufügen


# weitere LSTM Schicht hinzufügen, bei der nur die letzte Ausgabe (und nicht wie oben die ganze Sequenz) in die nächste Schicht weitergegeben wird
model.add(LSTM(units = UNITS, input_shape=(TIMESTEPS,1), name = 'lstm_' + str(N_LAYER+1)))

# Lineares Layer mit ReLU-Aktivierungsfunktion
model.add(Dense(units = 1, name='dense_1'))#, activation=activations.tanh))

# Konfiguriere das Modell für die Trainingsphase

# Angeben welcher Optimierer verwendet werden soll
opt = tf.keras.optimizers.Adam(learning_rate=0.005)

# über welche Verlustfunktion optimiert werden soll
# und wie die Performance des Modells gemessen werden soll (hier werden Verlustfunktion und Performancemetrik gleich gewählt, muss aber nicht so sein))
model.compile(optimizer = opt, loss = "mse", metrics=['mean_squared_error'])

# Zusammenfassung und Visualisierung des Modells
model.summary()
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 7, 10)             480
#
#  lstm_2 (LSTM)               (None, 7, 10)             840
#
#  lstm_3 (LSTM)               (None, 10)                840
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 2171 (8.48 KB)
# Trainable params: 2171 (8.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Aufgabe 3
#
# **Welchen Parameter der obigen Codezelle müssten Sie verändern, um 3 LSTM Schichten zu bekommen?**<br>
# die Parameter ``N_LAYER`` = 3 # Anzahl an LSTM-Schichten

# %% [markdown]
# # Aufgabe 4
#
# Das Neuronale Netz wird in der unten stehenden Codezelle trainiert. Führen Sie den Code aus. <br>
# **Nach wie vielen Epochen wird das Training auf jeden Fall stoppen?** <br>
# Das Training wird automatisch gestoppt, wenn der Validierungsverlust (monitor = 'val_loss') für 200 aufeinander folgende Epochen (patience = 200) nicht verbessert wird. <br>
# ``In diesem Fall wird das Training nach 737 Epochen gestoppt, das heißt nach Epoch 537 gab es keine Verbesserung des Validierungsverlusts.``

# %%
# Modell trainieren

# Erstelle Callback für Stop-Kriterium
from keras.callbacks import EarlyStopping, CSVLogger
cb_stop = EarlyStopping(monitor='val_loss', mode='min',
                        verbose=1, patience=200)
log_file = 'demo-py5-log.csv'
cb_logger = CSVLogger(log_file, append=False, separator=';')

# X_train erhält eine zusätzliche Dimension und wird dreidimensional
X_train = np.array(X_train)
X_train = np.reshape(X_train,
                     (X_train.shape[0], X_train.shape[1], 1))

print(X_train.shape)

# Trainiere das Modell mit Hilfe der Funktion fit()
BATCH_SIZE = 64
EPOCHS = 1000
history = model.fit(X_train, y_train,
                    epochs=EPOCHS, batch_size=BATCH_SIZE,
                    validation_split=TEST_SPLIT, verbose=2,
                    callbacks=[cb_logger, cb_stop])

# Speichere das Modell im Format HDF5
model.save("model_adam.h5")

print("History");print(history.history.keys());
# Out:
# (1308, 7, 1)
# Epoch 1/1000
# 19/19 - 16s - loss: 0.1532 - mean_squared_error: 0.1532 - val_loss: 0.0499 - val_mean_squared_error: 0.0499 - 16s/epoch - 857ms/step
# Epoch 2/1000
# 19/19 - 1s - loss: 0.0457 - mean_squared_error: 0.0457 - val_loss: 0.0530 - val_mean_squared_error: 0.0530 - 606ms/epoch - 32ms/step
# Epoch 3/1000
# 19/19 - 1s - loss: 0.0425 - mean_squared_error: 0.0425 - val_loss: 0.0468 - val_mean_squared_error: 0.0468 - 601ms/epoch - 32ms/step
# Epoch 4/1000
# 19/19 - 1s - loss: 0.0398 - mean_squared_error: 0.0398 - val_loss: 0.0447 - val_mean_squared_error: 0.0447 - 510ms/epoch - 27ms/step
# Epoch 5/1000
# 19/19 - 0s - loss: 0.0366 - mean_squared_error: 0.0366 - val_loss: 0.0400 - val_mean_squared_error: 0.0400 - 387ms/epoch - 20ms/step
# Epoch 6/1000
# 19/19 - 0s - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 0.0405 - val_mean_squared_error: 0.0405 - 406ms/epoch - 21ms/step
# Epoch 7/1000
# 19/19 - 1s - loss: 0.0328 - mean_squared_error: 0.0328 - val_loss: 0.0400 - val_mean_squared_error: 0.0400 - 652ms/epoch - 34ms/step
# Epoch 8/1000
# 19/19 - 0s - loss: 0.0328 - mean_squared_error: 0.0328 - val_loss: 0.0366 - val_mean_squared_error: 0.0366 - 468ms/epoch - 25ms/step
# Epoch 9/1000
# 19/19 - 0s - loss: 0.0293 - mean_squared_error: 0.0293 - val_loss: 0.0404 - val_mean_squared_error: 0.0404 - 466ms/epoch - 25ms/step
# Epoch 10/1000
# 19/19 - 0s - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0345 - val_mean_squared_error: 0.0345 - 428ms/epoch - 23ms/step
# Epoch 11/1000
# 19/19 - 1s - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0325 - val_mean_squared_error: 0.0325 - 537ms/epoch - 28ms/step
# Epoch 12/1000
# 19/19 - 0s - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0290 - val_mean_squared_error: 0.0290 - 450ms/epoch - 24ms/step
# Epoch 13/1000
# 19/19 - 0s - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - 434ms/epoch - 23ms/step
# Epoch 14/1000
# 19/19 - 0s - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0243 - val_mean_squared_error: 0.0243 - 374ms/epoch - 20ms/step
# Epoch 15/1000
# 19/19 - 1s - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0260 - val_mean_squared_error: 0.0260 - 563ms/epoch - 30ms/step
# Epoch 16/1000
# 19/19 - 1s - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0241 - val_mean_squared_error: 0.0241 - 506ms/epoch - 27ms/step
# Epoch 17/1000
# 19/19 - 0s - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0232 - val_mean_squared_error: 0.0232 - 376ms/epoch - 20ms/step
# Epoch 18/1000
# 19/19 - 0s - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0227 - val_mean_squared_error: 0.0227 - 381ms/epoch - 20ms/step
# Epoch 19/1000
# 19/19 - 0s - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0328 - val_mean_squared_error: 0.0328 - 377ms/epoch - 20ms/step
# Epoch 20/1000
# 19/19 - 0s - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0236 - val_mean_squared_error: 0.0236 - 379ms/epoch - 20ms/step
# Epoch 21/1000
# 19/19 - 0s - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0226 - val_mean_squared_error: 0.0226 - 374ms/epoch - 20ms/step
# Epoch 22/1000
# 19/19 - 0s - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0262 - val_mean_squared_error: 0.0262 - 377ms/epoch - 20ms/step
# Epoch 23/1000
# 19/19 - 0s - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0228 - val_mean_squared_error: 0.0228 - 380ms/epoch - 20ms/step
# Epoch 24/1000
# 19/19 - 0s - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0220 - val_mean_squared_error: 0.0220 - 372ms/epoch - 20ms/step
# Epoch 25/1000
# 19/19 - 0s - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - 364ms/epoch - 19ms/step
# Epoch 26/1000
# 19/19 - 0s - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0224 - val_mean_squared_error: 0.0224 - 380ms/epoch - 20ms/step
# Epoch 27/1000
# 19/19 - 0s - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - 329ms/epoch - 17ms/step
# Epoch 28/1000
# 19/19 - 0s - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0220 - val_mean_squared_error: 0.0220 - 254ms/epoch - 13ms/step
# Epoch 29/1000
# 19/19 - 0s - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0222 - val_mean_squared_error: 0.0222 - 263ms/epoch - 14ms/step
# Epoch 30/1000
# 19/19 - 0s - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0234 - val_mean_squared_error: 0.0234 - 261ms/epoch - 14ms/step
# Epoch 31/1000
# 19/19 - 0s - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - 263ms/epoch - 14ms/step
# Epoch 32/1000
# 19/19 - 0s - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0219 - val_mean_squared_error: 0.0219 - 262ms/epoch - 14ms/step
# Epoch 33/1000
# 19/19 - 0s - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - 258ms/epoch - 14ms/step
# Epoch 34/1000
# 19/19 - 0s - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0201 - val_mean_squared_error: 0.0201 - 244ms/epoch - 13ms/step
# Epoch 35/1000
# 19/19 - 0s - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0235 - val_mean_squared_error: 0.0235 - 260ms/epoch - 14ms/step
# Epoch 36/1000
# 19/19 - 0s - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - 240ms/epoch - 13ms/step
# Epoch 37/1000
# 19/19 - 0s - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0193 - val_mean_squared_error: 0.0193 - 259ms/epoch - 14ms/step
# Epoch 38/1000
# 19/19 - 0s - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - 253ms/epoch - 13ms/step
# Epoch 39/1000
# 19/19 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - 250ms/epoch - 13ms/step
# Epoch 40/1000
# 19/19 - 0s - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0193 - val_mean_squared_error: 0.0193 - 251ms/epoch - 13ms/step
# Epoch 41/1000
# 19/19 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0193 - val_mean_squared_error: 0.0193 - 245ms/epoch - 13ms/step
# Epoch 42/1000
# 19/19 - 0s - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0220 - val_mean_squared_error: 0.0220 - 259ms/epoch - 14ms/step
# Epoch 43/1000
# 19/19 - 0s - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0237 - val_mean_squared_error: 0.0237 - 262ms/epoch - 14ms/step
# Epoch 44/1000
# 19/19 - 0s - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0231 - val_mean_squared_error: 0.0231 - 257ms/epoch - 14ms/step
# Epoch 45/1000
# 19/19 - 0s - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - 265ms/epoch - 14ms/step
# Epoch 46/1000
# 19/19 - 0s - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - 255ms/epoch - 13ms/step
# Epoch 47/1000
# 19/19 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - 264ms/epoch - 14ms/step
# Epoch 48/1000
# 19/19 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - 261ms/epoch - 14ms/step
# Epoch 49/1000
# 19/19 - 0s - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0196 - val_mean_squared_error: 0.0196 - 269ms/epoch - 14ms/step
# Epoch 50/1000
# 19/19 - 0s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0193 - val_mean_squared_error: 0.0193 - 255ms/epoch - 13ms/step
# Epoch 51/1000
# 19/19 - 0s - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - 253ms/epoch - 13ms/step
# Epoch 52/1000
# 19/19 - 0s - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - 248ms/epoch - 13ms/step
# Epoch 53/1000
# 19/19 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - 258ms/epoch - 14ms/step
# Epoch 54/1000
# 19/19 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - 249ms/epoch - 13ms/step
# Epoch 55/1000
# 19/19 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0190 - val_mean_squared_error: 0.0190 - 261ms/epoch - 14ms/step
# Epoch 56/1000
# 19/19 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0196 - val_mean_squared_error: 0.0196 - 259ms/epoch - 14ms/step
# Epoch 57/1000
# 19/19 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - 255ms/epoch - 13ms/step
# Epoch 58/1000
# 19/19 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0192 - val_mean_squared_error: 0.0192 - 258ms/epoch - 14ms/step
# Epoch 59/1000
# 19/19 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0188 - val_mean_squared_error: 0.0188 - 244ms/epoch - 13ms/step
# Epoch 60/1000
# 19/19 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0191 - val_mean_squared_error: 0.0191 - 260ms/epoch - 14ms/step
# Epoch 61/1000
# 19/19 - 0s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0184 - val_mean_squared_error: 0.0184 - 253ms/epoch - 13ms/step
# Epoch 62/1000
# 19/19 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - 254ms/epoch - 13ms/step
# Epoch 63/1000
# 19/19 - 0s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - 241ms/epoch - 13ms/step
# Epoch 64/1000
# 19/19 - 0s - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0186 - val_mean_squared_error: 0.0186 - 275ms/epoch - 14ms/step
# Epoch 65/1000
# 19/19 - 0s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0190 - val_mean_squared_error: 0.0190 - 285ms/epoch - 15ms/step
# Epoch 66/1000
# 19/19 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0186 - val_mean_squared_error: 0.0186 - 370ms/epoch - 19ms/step
# Epoch 67/1000
# 19/19 - 0s - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0182 - val_mean_squared_error: 0.0182 - 374ms/epoch - 20ms/step
# Epoch 68/1000
# 19/19 - 0s - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0184 - val_mean_squared_error: 0.0184 - 375ms/epoch - 20ms/step
# Epoch 69/1000
# 19/19 - 0s - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - 362ms/epoch - 19ms/step
# Epoch 70/1000
# 19/19 - 0s - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0180 - val_mean_squared_error: 0.0180 - 356ms/epoch - 19ms/step
# Epoch 71/1000
# 19/19 - 0s - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0177 - val_mean_squared_error: 0.0177 - 354ms/epoch - 19ms/step
# Epoch 72/1000
# 19/19 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0188 - val_mean_squared_error: 0.0188 - 379ms/epoch - 20ms/step
# Epoch 73/1000
# 19/19 - 0s - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0181 - val_mean_squared_error: 0.0181 - 375ms/epoch - 20ms/step
# Epoch 74/1000
# 19/19 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0177 - val_mean_squared_error: 0.0177 - 353ms/epoch - 19ms/step
# Epoch 75/1000
# 19/19 - 0s - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0181 - val_mean_squared_error: 0.0181 - 367ms/epoch - 19ms/step
# Epoch 76/1000
# 19/19 - 0s - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0182 - val_mean_squared_error: 0.0182 - 371ms/epoch - 20ms/step
# Epoch 77/1000
# 19/19 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0176 - val_mean_squared_error: 0.0176 - 343ms/epoch - 18ms/step
# Epoch 78/1000
# 19/19 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0184 - val_mean_squared_error: 0.0184 - 266ms/epoch - 14ms/step
# Epoch 79/1000
# 19/19 - 0s - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0184 - val_mean_squared_error: 0.0184 - 271ms/epoch - 14ms/step
# Epoch 80/1000
# 19/19 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0180 - val_mean_squared_error: 0.0180 - 263ms/epoch - 14ms/step
# Epoch 81/1000
# 19/19 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - 260ms/epoch - 14ms/step
# Epoch 82/1000
# 19/19 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0173 - val_mean_squared_error: 0.0173 - 267ms/epoch - 14ms/step
# Epoch 83/1000
# 19/19 - 0s - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0174 - val_mean_squared_error: 0.0174 - 256ms/epoch - 13ms/step
# Epoch 84/1000
# 19/19 - 0s - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0177 - val_mean_squared_error: 0.0177 - 257ms/epoch - 14ms/step
# Epoch 85/1000
# 19/19 - 0s - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0174 - val_mean_squared_error: 0.0174 - 240ms/epoch - 13ms/step
# Epoch 86/1000
# 19/19 - 0s - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0174 - val_mean_squared_error: 0.0174 - 255ms/epoch - 13ms/step
# Epoch 87/1000
# 19/19 - 0s - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0189 - val_mean_squared_error: 0.0189 - 265ms/epoch - 14ms/step
# Epoch 88/1000
# 19/19 - 0s - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0169 - val_mean_squared_error: 0.0169 - 275ms/epoch - 14ms/step
# Epoch 89/1000
# 19/19 - 0s - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0167 - val_mean_squared_error: 0.0167 - 253ms/epoch - 13ms/step
# Epoch 90/1000
# 19/19 - 0s - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0165 - val_mean_squared_error: 0.0165 - 245ms/epoch - 13ms/step
# Epoch 91/1000
# 19/19 - 0s - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0166 - val_mean_squared_error: 0.0166 - 268ms/epoch - 14ms/step
# Epoch 92/1000
# 19/19 - 0s - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0172 - val_mean_squared_error: 0.0172 - 256ms/epoch - 13ms/step
# Epoch 93/1000
# 19/19 - 0s - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0166 - val_mean_squared_error: 0.0166 - 259ms/epoch - 14ms/step
# Epoch 94/1000
# 19/19 - 0s - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0179 - val_mean_squared_error: 0.0179 - 257ms/epoch - 14ms/step
# Epoch 95/1000
# 19/19 - 0s - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0176 - val_mean_squared_error: 0.0176 - 267ms/epoch - 14ms/step
# Epoch 96/1000
# 19/19 - 0s - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0161 - val_mean_squared_error: 0.0161 - 253ms/epoch - 13ms/step
# Epoch 97/1000
# 19/19 - 0s - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0160 - val_mean_squared_error: 0.0160 - 255ms/epoch - 13ms/step
# Epoch 98/1000
# 19/19 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0161 - val_mean_squared_error: 0.0161 - 265ms/epoch - 14ms/step
# Epoch 99/1000
# 19/19 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0156 - val_mean_squared_error: 0.0156 - 252ms/epoch - 13ms/step
# Epoch 100/1000
# 19/19 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0161 - val_mean_squared_error: 0.0161 - 256ms/epoch - 13ms/step
# Epoch 101/1000
# 19/19 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0166 - val_mean_squared_error: 0.0166 - 250ms/epoch - 13ms/step
# Epoch 102/1000
# 19/19 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0157 - val_mean_squared_error: 0.0157 - 250ms/epoch - 13ms/step
# Epoch 103/1000
# 19/19 - 0s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0156 - val_mean_squared_error: 0.0156 - 275ms/epoch - 14ms/step
# Epoch 104/1000
# 19/19 - 0s - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0155 - val_mean_squared_error: 0.0155 - 241ms/epoch - 13ms/step
# Epoch 105/1000
# 19/19 - 0s - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0154 - val_mean_squared_error: 0.0154 - 246ms/epoch - 13ms/step
# Epoch 106/1000
# 19/19 - 0s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0151 - val_mean_squared_error: 0.0151 - 251ms/epoch - 13ms/step
# Epoch 107/1000
# 19/19 - 0s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0156 - val_mean_squared_error: 0.0156 - 241ms/epoch - 13ms/step
# Epoch 108/1000
# 19/19 - 0s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0153 - val_mean_squared_error: 0.0153 - 257ms/epoch - 14ms/step
# Epoch 109/1000
# 19/19 - 0s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0159 - val_mean_squared_error: 0.0159 - 245ms/epoch - 13ms/step
# Epoch 110/1000
# 19/19 - 0s - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0155 - val_mean_squared_error: 0.0155 - 252ms/epoch - 13ms/step
# Epoch 111/1000
# 19/19 - 0s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0155 - val_mean_squared_error: 0.0155 - 241ms/epoch - 13ms/step
# Epoch 112/1000
# 19/19 - 0s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - 254ms/epoch - 13ms/step
# Epoch 113/1000
# 19/19 - 0s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0152 - val_mean_squared_error: 0.0152 - 253ms/epoch - 13ms/step
# Epoch 114/1000
# 19/19 - 0s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0152 - val_mean_squared_error: 0.0152 - 255ms/epoch - 13ms/step
# Epoch 115/1000
# 19/19 - 0s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0146 - val_mean_squared_error: 0.0146 - 265ms/epoch - 14ms/step
# Epoch 116/1000
# 19/19 - 0s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - 354ms/epoch - 19ms/step
# Epoch 117/1000
# 19/19 - 0s - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - 358ms/epoch - 19ms/step
# Epoch 118/1000
# 19/19 - 0s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0151 - val_mean_squared_error: 0.0151 - 386ms/epoch - 20ms/step
# Epoch 119/1000
# 19/19 - 0s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - 372ms/epoch - 20ms/step
# Epoch 120/1000
# 19/19 - 0s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0151 - val_mean_squared_error: 0.0151 - 371ms/epoch - 20ms/step
# Epoch 121/1000
# 19/19 - 0s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0157 - val_mean_squared_error: 0.0157 - 359ms/epoch - 19ms/step
# Epoch 122/1000
# 19/19 - 0s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0147 - val_mean_squared_error: 0.0147 - 379ms/epoch - 20ms/step
# Epoch 123/1000
# 19/19 - 0s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0154 - val_mean_squared_error: 0.0154 - 384ms/epoch - 20ms/step
# Epoch 124/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - 371ms/epoch - 20ms/step
# Epoch 125/1000
# 19/19 - 0s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - 357ms/epoch - 19ms/step
# Epoch 126/1000
# 19/19 - 0s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - 369ms/epoch - 19ms/step
# Epoch 127/1000
# 19/19 - 0s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - 333ms/epoch - 18ms/step
# Epoch 128/1000
# 19/19 - 0s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0142 - val_mean_squared_error: 0.0142 - 253ms/epoch - 13ms/step
# Epoch 129/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 249ms/epoch - 13ms/step
# Epoch 130/1000
# 19/19 - 0s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0146 - val_mean_squared_error: 0.0146 - 259ms/epoch - 14ms/step
# Epoch 131/1000
# 19/19 - 0s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 263ms/epoch - 14ms/step
# Epoch 132/1000
# 19/19 - 0s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 248ms/epoch - 13ms/step
# Epoch 133/1000
# 19/19 - 0s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 250ms/epoch - 13ms/step
# Epoch 134/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 240ms/epoch - 13ms/step
# Epoch 135/1000
# 19/19 - 0s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 261ms/epoch - 14ms/step
# Epoch 136/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0141 - val_mean_squared_error: 0.0141 - 252ms/epoch - 13ms/step
# Epoch 137/1000
# 19/19 - 0s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 304ms/epoch - 16ms/step
# Epoch 138/1000
# 19/19 - 0s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - 252ms/epoch - 13ms/step
# Epoch 139/1000
# 19/19 - 0s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - 251ms/epoch - 13ms/step
# Epoch 140/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - 251ms/epoch - 13ms/step
# Epoch 141/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 255ms/epoch - 13ms/step
# Epoch 142/1000
# 19/19 - 0s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 247ms/epoch - 13ms/step
# Epoch 143/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 256ms/epoch - 13ms/step
# Epoch 144/1000
# 19/19 - 0s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0153 - val_mean_squared_error: 0.0153 - 259ms/epoch - 14ms/step
# Epoch 145/1000
# 19/19 - 0s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0147 - val_mean_squared_error: 0.0147 - 266ms/epoch - 14ms/step
# Epoch 146/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0143 - val_mean_squared_error: 0.0143 - 263ms/epoch - 14ms/step
# Epoch 147/1000
# 19/19 - 0s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 274ms/epoch - 14ms/step
# Epoch 148/1000
# 19/19 - 0s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - 244ms/epoch - 13ms/step
# Epoch 149/1000
# 19/19 - 0s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 258ms/epoch - 14ms/step
# Epoch 150/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 265ms/epoch - 14ms/step
# Epoch 151/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - 262ms/epoch - 14ms/step
# Epoch 152/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - 243ms/epoch - 13ms/step
# Epoch 153/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 254ms/epoch - 13ms/step
# Epoch 154/1000
# 19/19 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 253ms/epoch - 13ms/step
# Epoch 155/1000
# 19/19 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 262ms/epoch - 14ms/step
# Epoch 156/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 244ms/epoch - 13ms/step
# Epoch 157/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - 268ms/epoch - 14ms/step
# Epoch 158/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - 252ms/epoch - 13ms/step
# Epoch 159/1000
# 19/19 - 0s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 255ms/epoch - 13ms/step
# Epoch 160/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - 242ms/epoch - 13ms/step
# Epoch 161/1000
# 19/19 - 0s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - 248ms/epoch - 13ms/step
# Epoch 162/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 248ms/epoch - 13ms/step
# Epoch 163/1000
# 19/19 - 0s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 253ms/epoch - 13ms/step
# Epoch 164/1000
# 19/19 - 0s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 251ms/epoch - 13ms/step
# Epoch 165/1000
# 19/19 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0143 - val_mean_squared_error: 0.0143 - 259ms/epoch - 14ms/step
# Epoch 166/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - 371ms/epoch - 20ms/step
# Epoch 167/1000
# 19/19 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0129 - val_mean_squared_error: 0.0129 - 361ms/epoch - 19ms/step
# Epoch 168/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - 411ms/epoch - 22ms/step
# Epoch 169/1000
# 19/19 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 386ms/epoch - 20ms/step
# Epoch 170/1000
# 19/19 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - 359ms/epoch - 19ms/step
# Epoch 171/1000
# 19/19 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - 367ms/epoch - 19ms/step
# Epoch 172/1000
# 19/19 - 0s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - 369ms/epoch - 19ms/step
# Epoch 173/1000
# 19/19 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - 395ms/epoch - 21ms/step
# Epoch 174/1000
# 19/19 - 0s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - 360ms/epoch - 19ms/step
# Epoch 175/1000
# 19/19 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - 362ms/epoch - 19ms/step
# Epoch 176/1000
# 19/19 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - 376ms/epoch - 20ms/step
# Epoch 177/1000
# 19/19 - 0s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - 314ms/epoch - 17ms/step
# Epoch 178/1000
# 19/19 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - 260ms/epoch - 14ms/step
# Epoch 179/1000
# 19/19 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - 249ms/epoch - 13ms/step
# Epoch 180/1000
# 19/19 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - 267ms/epoch - 14ms/step
# Epoch 181/1000
# 19/19 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - 254ms/epoch - 13ms/step
# Epoch 182/1000
# 19/19 - 0s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - 256ms/epoch - 13ms/step
# Epoch 183/1000
# 19/19 - 0s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0147 - val_mean_squared_error: 0.0147 - 263ms/epoch - 14ms/step
# Epoch 184/1000
# 19/19 - 0s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - 268ms/epoch - 14ms/step
# Epoch 185/1000
# 19/19 - 0s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - 254ms/epoch - 13ms/step
# Epoch 186/1000
# 19/19 - 0s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0142 - val_mean_squared_error: 0.0142 - 254ms/epoch - 13ms/step
# Epoch 187/1000
# 19/19 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - 249ms/epoch - 13ms/step
# Epoch 188/1000
# 19/19 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0129 - val_mean_squared_error: 0.0129 - 257ms/epoch - 14ms/step
# Epoch 189/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 251ms/epoch - 13ms/step
# Epoch 190/1000
# 19/19 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 256ms/epoch - 13ms/step
# Epoch 191/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - 273ms/epoch - 14ms/step
# Epoch 192/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - 247ms/epoch - 13ms/step
# Epoch 193/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - 253ms/epoch - 13ms/step
# Epoch 194/1000
# 19/19 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - 256ms/epoch - 13ms/step
# Epoch 195/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - 261ms/epoch - 14ms/step
# Epoch 196/1000
# 19/19 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 254ms/epoch - 13ms/step
# Epoch 197/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - 246ms/epoch - 13ms/step
# Epoch 198/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - 255ms/epoch - 13ms/step
# Epoch 199/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - 266ms/epoch - 14ms/step
# Epoch 200/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - 249ms/epoch - 13ms/step
# Epoch 201/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - 256ms/epoch - 13ms/step
# Epoch 202/1000
# 19/19 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - 256ms/epoch - 13ms/step
# Epoch 203/1000
# 19/19 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - 268ms/epoch - 14ms/step
# Epoch 204/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - 256ms/epoch - 13ms/step
# Epoch 205/1000
# 19/19 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - 249ms/epoch - 13ms/step
# Epoch 206/1000
# 19/19 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 256ms/epoch - 13ms/step
# Epoch 207/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - 258ms/epoch - 14ms/step
# Epoch 208/1000
# 19/19 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - 267ms/epoch - 14ms/step
# Epoch 209/1000
# 19/19 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 241ms/epoch - 13ms/step
# Epoch 210/1000
# 19/19 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - 255ms/epoch - 13ms/step
# Epoch 211/1000
# 19/19 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - 270ms/epoch - 14ms/step
# Epoch 212/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - 260ms/epoch - 14ms/step
# Epoch 213/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - 255ms/epoch - 13ms/step
# Epoch 214/1000
# 19/19 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - 243ms/epoch - 13ms/step
# Epoch 215/1000
# 19/19 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 304ms/epoch - 16ms/step
# Epoch 216/1000
# 19/19 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - 360ms/epoch - 19ms/step
# Epoch 217/1000
# 19/19 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - 360ms/epoch - 19ms/step
# Epoch 218/1000
# 19/19 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - 384ms/epoch - 20ms/step
# Epoch 219/1000
# 19/19 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 363ms/epoch - 19ms/step
# Epoch 220/1000
# 19/19 - 0s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 349ms/epoch - 18ms/step
# Epoch 221/1000
# 19/19 - 0s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 373ms/epoch - 20ms/step
# Epoch 222/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - 369ms/epoch - 19ms/step
# Epoch 223/1000
# 19/19 - 0s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 379ms/epoch - 20ms/step
# Epoch 224/1000
# 19/19 - 0s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - 355ms/epoch - 19ms/step
# Epoch 225/1000
# 19/19 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 367ms/epoch - 19ms/step
# Epoch 226/1000
# 19/19 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 370ms/epoch - 19ms/step
# Epoch 227/1000
# 19/19 - 0s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 344ms/epoch - 18ms/step
# Epoch 228/1000
# 19/19 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - 262ms/epoch - 14ms/step
# Epoch 229/1000
# 19/19 - 0s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 241ms/epoch - 13ms/step
# Epoch 230/1000
# 19/19 - 0s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 262ms/epoch - 14ms/step
# Epoch 231/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - 262ms/epoch - 14ms/step
# Epoch 232/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - 243ms/epoch - 13ms/step
# Epoch 233/1000
# 19/19 - 0s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - 245ms/epoch - 13ms/step
# Epoch 234/1000
# 19/19 - 0s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - 272ms/epoch - 14ms/step
# Epoch 235/1000
# 19/19 - 0s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0143 - val_mean_squared_error: 0.0143 - 245ms/epoch - 13ms/step
# Epoch 236/1000
# 19/19 - 0s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 263ms/epoch - 14ms/step
# Epoch 237/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 251ms/epoch - 13ms/step
# Epoch 238/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - 264ms/epoch - 14ms/step
# Epoch 239/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - 272ms/epoch - 14ms/step
# Epoch 240/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 265ms/epoch - 14ms/step
# Epoch 241/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - 268ms/epoch - 14ms/step
# Epoch 242/1000
# 19/19 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 246ms/epoch - 13ms/step
# Epoch 243/1000
# 19/19 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - 254ms/epoch - 13ms/step
# Epoch 244/1000
# 19/19 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 255ms/epoch - 13ms/step
# Epoch 245/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 248ms/epoch - 13ms/step
# Epoch 246/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 265ms/epoch - 14ms/step
# Epoch 247/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 259ms/epoch - 14ms/step
# Epoch 248/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 252ms/epoch - 13ms/step
# Epoch 249/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 253ms/epoch - 13ms/step
# Epoch 250/1000
# 19/19 - 0s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 262ms/epoch - 14ms/step
# Epoch 251/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - 253ms/epoch - 13ms/step
# Epoch 252/1000
# 19/19 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 253ms/epoch - 13ms/step
# Epoch 253/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - 261ms/epoch - 14ms/step
# Epoch 254/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 244ms/epoch - 13ms/step
# Epoch 255/1000
# 19/19 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 241ms/epoch - 13ms/step
# Epoch 256/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 259ms/epoch - 14ms/step
# Epoch 257/1000
# 19/19 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - 267ms/epoch - 14ms/step
# Epoch 258/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 241ms/epoch - 13ms/step
# Epoch 259/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 257ms/epoch - 14ms/step
# Epoch 260/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 253ms/epoch - 13ms/step
# Epoch 261/1000
# 19/19 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - 267ms/epoch - 14ms/step
# Epoch 262/1000
# 19/19 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 245ms/epoch - 13ms/step
# Epoch 263/1000
# 19/19 - 0s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 250ms/epoch - 13ms/step
# Epoch 264/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - 259ms/epoch - 14ms/step
# Epoch 265/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 252ms/epoch - 13ms/step
# Epoch 266/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 358ms/epoch - 19ms/step
# Epoch 267/1000
# 19/19 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 358ms/epoch - 19ms/step
# Epoch 268/1000
# 19/19 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 377ms/epoch - 20ms/step
# Epoch 269/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - 385ms/epoch - 20ms/step
# Epoch 270/1000
# 19/19 - 0s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 356ms/epoch - 19ms/step
# Epoch 271/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - 376ms/epoch - 20ms/step
# Epoch 272/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - 363ms/epoch - 19ms/step
# Epoch 273/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 369ms/epoch - 19ms/step
# Epoch 274/1000
# 19/19 - 0s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - 362ms/epoch - 19ms/step
# Epoch 275/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 364ms/epoch - 19ms/step
# Epoch 276/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 379ms/epoch - 20ms/step
# Epoch 277/1000
# 19/19 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 352ms/epoch - 19ms/step
# Epoch 278/1000
# 19/19 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 262ms/epoch - 14ms/step
# Epoch 279/1000
# 19/19 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 255ms/epoch - 13ms/step
# Epoch 280/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0129 - val_mean_squared_error: 0.0129 - 270ms/epoch - 14ms/step
# Epoch 281/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - 270ms/epoch - 14ms/step
# Epoch 282/1000
# 19/19 - 0s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 259ms/epoch - 14ms/step
# Epoch 283/1000
# 19/19 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 259ms/epoch - 14ms/step
# Epoch 284/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 253ms/epoch - 13ms/step
# Epoch 285/1000
# 19/19 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 245ms/epoch - 13ms/step
# Epoch 286/1000
# 19/19 - 0s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 253ms/epoch - 13ms/step
# Epoch 287/1000
# 19/19 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 257ms/epoch - 14ms/step
# Epoch 288/1000
# 19/19 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 261ms/epoch - 14ms/step
# Epoch 289/1000
# 19/19 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 251ms/epoch - 13ms/step
# Epoch 290/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 243ms/epoch - 13ms/step
# Epoch 291/1000
# 19/19 - 0s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 259ms/epoch - 14ms/step
# Epoch 292/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 268ms/epoch - 14ms/step
# Epoch 293/1000
# 19/19 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 240ms/epoch - 13ms/step
# Epoch 294/1000
# 19/19 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 252ms/epoch - 13ms/step
# Epoch 295/1000
# 19/19 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 241ms/epoch - 13ms/step
# Epoch 296/1000
# 19/19 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 270ms/epoch - 14ms/step
# Epoch 297/1000
# 19/19 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 263ms/epoch - 14ms/step
# Epoch 298/1000
# 19/19 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 243ms/epoch - 13ms/step
# Epoch 299/1000
# 19/19 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 259ms/epoch - 14ms/step
# Epoch 300/1000
# 19/19 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 254ms/epoch - 13ms/step
# Epoch 301/1000
# 19/19 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 250ms/epoch - 13ms/step
# Epoch 302/1000
# 19/19 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 263ms/epoch - 14ms/step
# Epoch 303/1000
# 19/19 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 276ms/epoch - 15ms/step
# Epoch 304/1000
# 19/19 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - 265ms/epoch - 14ms/step
# Epoch 305/1000
# 19/19 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 251ms/epoch - 13ms/step
# Epoch 306/1000
# 19/19 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 239ms/epoch - 13ms/step
# Epoch 307/1000
# 19/19 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - 258ms/epoch - 14ms/step
# Epoch 308/1000
# 19/19 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0129 - val_mean_squared_error: 0.0129 - 259ms/epoch - 14ms/step
# Epoch 309/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 246ms/epoch - 13ms/step
# Epoch 310/1000
# 19/19 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 270ms/epoch - 14ms/step
# Epoch 311/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 264ms/epoch - 14ms/step
# Epoch 312/1000
# 19/19 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 266ms/epoch - 14ms/step
# Epoch 313/1000
# 19/19 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 254ms/epoch - 13ms/step
# Epoch 314/1000
# 19/19 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 241ms/epoch - 13ms/step
# Epoch 315/1000
# 19/19 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 283ms/epoch - 15ms/step
# Epoch 316/1000
# 19/19 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 362ms/epoch - 19ms/step
# Epoch 317/1000
# 19/19 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 373ms/epoch - 20ms/step
# Epoch 318/1000
# 19/19 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 371ms/epoch - 20ms/step
# Epoch 319/1000
# 19/19 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 392ms/epoch - 21ms/step
# Epoch 320/1000
# 19/19 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 352ms/epoch - 19ms/step
# Epoch 321/1000
# 19/19 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 372ms/epoch - 20ms/step
# Epoch 322/1000
# 19/19 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 379ms/epoch - 20ms/step
# Epoch 323/1000
# 19/19 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - 411ms/epoch - 22ms/step
# Epoch 324/1000
# 19/19 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 365ms/epoch - 19ms/step
# Epoch 325/1000
# ...
# Epoch 412/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 244ms/epoch - 13ms/step
# Epoch 413/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 351ms/epoch - 18ms/step
# Epoch 414/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 370ms/epoch - 19ms/step
# Epoch 415/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 368ms/epoch - 19ms/step
# Epoch 416/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 382ms/epoch - 20ms/step
# Epoch 417/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 370ms/epoch - 19ms/step
# Epoch 418/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 352ms/epoch - 19ms/step
# Epoch 419/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 386ms/epoch - 20ms/step
# Epoch 420/1000
# 19/19 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 389ms/epoch - 20ms/step
# Epoch 421/1000
# 19/19 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 377ms/epoch - 20ms/step
# Epoch 422/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 359ms/epoch - 19ms/step
# Epoch 423/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 406ms/epoch - 21ms/step
# Epoch 424/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 372ms/epoch - 20ms/step
# Epoch 425/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 246ms/epoch - 13ms/step
# Epoch 426/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 248ms/epoch - 13ms/step
# Epoch 427/1000
# 19/19 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 266ms/epoch - 14ms/step
# Epoch 428/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 256ms/epoch - 13ms/step
# Epoch 429/1000
# 19/19 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 265ms/epoch - 14ms/step
# Epoch 430/1000
# 19/19 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 256ms/epoch - 13ms/step
# Epoch 431/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 257ms/epoch - 14ms/step
# Epoch 432/1000
# 19/19 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 269ms/epoch - 14ms/step
# Epoch 433/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 242ms/epoch - 13ms/step
# Epoch 434/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 250ms/epoch - 13ms/step
# Epoch 435/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 250ms/epoch - 13ms/step
# Epoch 436/1000
# 19/19 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 267ms/epoch - 14ms/step
# Epoch 437/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 248ms/epoch - 13ms/step
# Epoch 438/1000
# 19/19 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 254ms/epoch - 13ms/step
# Epoch 439/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 256ms/epoch - 13ms/step
# Epoch 440/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 268ms/epoch - 14ms/step
# Epoch 441/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 242ms/epoch - 13ms/step
# Epoch 442/1000
# 19/19 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 268ms/epoch - 14ms/step
# Epoch 443/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 246ms/epoch - 13ms/step
# Epoch 444/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 267ms/epoch - 14ms/step
# Epoch 445/1000
# 19/19 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 249ms/epoch - 13ms/step
# Epoch 446/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 274ms/epoch - 14ms/step
# Epoch 447/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 247ms/epoch - 13ms/step
# Epoch 448/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 270ms/epoch - 14ms/step
# Epoch 449/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 262ms/epoch - 14ms/step
# Epoch 450/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 255ms/epoch - 13ms/step
# Epoch 451/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 256ms/epoch - 13ms/step
# Epoch 452/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 268ms/epoch - 14ms/step
# Epoch 453/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 248ms/epoch - 13ms/step
# Epoch 454/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 257ms/epoch - 14ms/step
# Epoch 455/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 261ms/epoch - 14ms/step
# Epoch 456/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 251ms/epoch - 13ms/step
# Epoch 457/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - 259ms/epoch - 14ms/step
# Epoch 458/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 262ms/epoch - 14ms/step
# Epoch 459/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 265ms/epoch - 14ms/step
# Epoch 460/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 251ms/epoch - 13ms/step
# Epoch 461/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 253ms/epoch - 13ms/step
# Epoch 462/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 259ms/epoch - 14ms/step
# Epoch 463/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 382ms/epoch - 20ms/step
# Epoch 464/1000
# 19/19 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 367ms/epoch - 19ms/step
# Epoch 465/1000
# 19/19 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 369ms/epoch - 19ms/step
# Epoch 466/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 381ms/epoch - 20ms/step
# Epoch 467/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 381ms/epoch - 20ms/step
# Epoch 468/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 347ms/epoch - 18ms/step
# Epoch 469/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 371ms/epoch - 20ms/step
# Epoch 470/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 365ms/epoch - 19ms/step
# Epoch 471/1000
# 19/19 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 364ms/epoch - 19ms/step
# Epoch 472/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 362ms/epoch - 19ms/step
# Epoch 473/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 372ms/epoch - 20ms/step
# Epoch 474/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 376ms/epoch - 20ms/step
# Epoch 475/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 259ms/epoch - 14ms/step
# Epoch 476/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 248ms/epoch - 13ms/step
# Epoch 477/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 252ms/epoch - 13ms/step
# Epoch 478/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 273ms/epoch - 14ms/step
# Epoch 479/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 259ms/epoch - 14ms/step
# Epoch 480/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 266ms/epoch - 14ms/step
# Epoch 481/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 255ms/epoch - 13ms/step
# Epoch 482/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 268ms/epoch - 14ms/step
# Epoch 483/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 266ms/epoch - 14ms/step
# Epoch 484/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 253ms/epoch - 13ms/step
# Epoch 485/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 250ms/epoch - 13ms/step
# Epoch 486/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 255ms/epoch - 13ms/step
# Epoch 487/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 265ms/epoch - 14ms/step
# Epoch 488/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 268ms/epoch - 14ms/step
# Epoch 489/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 249ms/epoch - 13ms/step
# Epoch 490/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 253ms/epoch - 13ms/step
# Epoch 491/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 264ms/epoch - 14ms/step
# Epoch 492/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 253ms/epoch - 13ms/step
# Epoch 493/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 240ms/epoch - 13ms/step
# Epoch 494/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 269ms/epoch - 14ms/step
# Epoch 495/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 257ms/epoch - 14ms/step
# Epoch 496/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 263ms/epoch - 14ms/step
# Epoch 497/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 259ms/epoch - 14ms/step
# Epoch 498/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 271ms/epoch - 14ms/step
# Epoch 499/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 267ms/epoch - 14ms/step
# Epoch 500/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 249ms/epoch - 13ms/step
# Epoch 501/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 267ms/epoch - 14ms/step
# Epoch 502/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 261ms/epoch - 14ms/step
# Epoch 503/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 258ms/epoch - 14ms/step
# Epoch 504/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 266ms/epoch - 14ms/step
# Epoch 505/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 251ms/epoch - 13ms/step
# Epoch 506/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 256ms/epoch - 13ms/step
# Epoch 507/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 259ms/epoch - 14ms/step
# Epoch 508/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 256ms/epoch - 13ms/step
# Epoch 509/1000
# 19/19 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 263ms/epoch - 14ms/step
# Epoch 510/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 250ms/epoch - 13ms/step
# Epoch 511/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 272ms/epoch - 14ms/step
# Epoch 512/1000
# 19/19 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 278ms/epoch - 15ms/step
# Epoch 513/1000
# 19/19 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 413ms/epoch - 22ms/step
# Epoch 514/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 370ms/epoch - 19ms/step
# Epoch 515/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 400ms/epoch - 21ms/step
# Epoch 516/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 368ms/epoch - 19ms/step
# Epoch 516: early stopping
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# History
# dict_keys(['loss', 'mean_squared_error', 'val_loss', 'val_mean_squared_error'])

# %% [markdown]
# # Aufgabe 5
#
# Im untenstehenden Codeblock wird der Trainingsfortschritt geplottet. <br>
# **Wie beurteilen Sie ihn?** <br>
# Die Tendenz für MSE lautet, dass dies sich im Laufe des Training an 0 nähert. Je näher der Wert an 0 liegt, desto besser ist das Modell. <br>
# Mit kleinen Abweichungen nach 600 und 800 wird diese Tendenz behalten, also ist der Trainingsfortschritt für die Vorhersage sehr gut.

# %%
# Trainingsfortschritt plotten

plt.plot(history.history['mean_squared_error'], label='MSE (Trainingsdaten)')
plt.plot(history.history['val_mean_squared_error'], label='MSE (Testdaten)')

plt.title('Training: Entwicklung des Fehlers')
plt.ylabel('MSE-Fehler')
plt.xlabel('Epochen')
plt.legend()

# %%
# Testdaten in Merkmale X und Label y aufteilen

X_test = test_s.drop(columns = ['Verbrauch'])
y_test = pd.DataFrame(test_s['Verbrauch'])

# Vorhersage für skalierte Testdaten
X_test = np.array(X_test)
X_test_input = np.reshape(X_test,
        (X_test.shape[0], X_test.shape[1], 1))

y_test = np.array(y_test)
#y_test = np.reshape(y_test,
        # (y_test.shape[0],  1))
y_pred = model.predict(X_test_input)

pred = np.concatenate((X_test, y_pred), axis=1)

# Reskaliere die Daten
test_rs = pd.DataFrame(scaler.inverse_transform(test_s), columns = test_s.columns)
pred_rs = pd.DataFrame(scaler.inverse_transform(pred), columns = test_s.columns)

y_test = test_rs['Verbrauch']
y_pred = pred_rs['Verbrauch']

# Berechne RMSE der Validierungsdaten
mse = mean_squared_error(y_test, y_pred)
rmse = np.round(np.sqrt(mse))
print("Validierungs-Fehler:")
print("\nMSE:\n %.2lf" % (mse))
# Out:
# 5/5 [==============================] - 1s 5ms/step
# Validierungs-Fehler:
#
# MSE:
#  4104.20

# %%
def rel_error(df, col1, col2):
    df['Error (%)'] = (df[col1] - df[col2]) / df[col1]  * 100
    df['Error (%)'] = df['Error (%)'].abs()
    return df['Error (%)']

# %%
# Hilfsfunktion error_table erzeugt Fehlertabelle
def error_table(df1, df2, col1, col2, idx):
    cols = [df1, df2]
    headers = [col1, col2]
    # Erzeuge pred aus y_test und y_pred mit Index idx
    pred = pd.concat(cols, axis=1, keys=headers)
    pred.set_index(idx, inplace=True)
    # Füge Fehler-Spalten hinzu
    pred['Error'] = np.abs(pred['y_test'] - pred['y_pred'])
    pred['Error(%)'] = rel_error(pred, 'y_test', 'y_pred')
    pred = pred.astype(float).round(1)
    # Füge RMSE hinzu
    mse = mean_squared_error(df1, df2)
    rmse = np.round(np.sqrt(mse))
    pred.index.name = "RMSE: " + str(rmse)
    return pred

# Erzeuge Fehlertabelle für Validierung und gebe sie aus
idx = test.index;
pred = error_table(pd.DataFrame(y_test), pd.DataFrame(y_pred), 'y_test', 'y_pred', idx)

pred.head()
# Out:
#               y_test    y_pred Error Error (%) Error(%)
#            Verbrauch Verbrauch
# RMSE: 64.0
# 2019-08-08    1326.6    1343.1  16.4       1.2      1.2
# 2019-08-09    1318.8    1317.7   1.0       0.1      0.1
# 2019-08-10    1132.4    1172.9  40.5       3.6      3.6
# 2019-08-11    1043.5    1123.0  79.5       7.6      7.6
# 2019-08-12    1299.0    1327.6  28.6       2.2      2.2

# %%
pred['Error (%)'].min()
# Out:
# 0.0

# %%
pred['Error (%)'].max()
# Out:
# 22.9

# %% [markdown]
# #### Mit einer maximalen Fehlerrate von 30.1 % und Mittelwert von 3.63 % kann man behaupten, dass das Vorhersagemodell zwar gut ist, aber wenig bis keine industrielle Anwendung finden kann.
